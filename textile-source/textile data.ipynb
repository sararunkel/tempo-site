# %%
import geojson
import pandas as pd
import geopandas as gpd

# %%
gpd.read_file('HAQ_TEMPO_NO2_CONUS_QA75_L3_Monthly_012024_12Z_V3.geojson')
# Out:
#      OBJECTID         FIPS  FIPS_new field_avg  \
# 0           5  08035014300      8035      None
# 1           6  08035014107      8035      None
# 2           7  08035013904      8035      None
# 3           8  08035014503      8035      None
# 4          11  08035014108      8035      None
# ..        ...          ...       ...       ...
# 863      1435  08001008526      8001      None
# 864      1436  08001060100      8001      None
# 865      1437  08001060200      8001      None
# 866      1444  08001008538      8001      None
# 867      1445  08001015000      8001      None
#
#                                               geometry
# 0    POLYGON ((-105.32923 39.1297, -105.32946 39.12...
# 1    POLYGON ((-104.98894 39.5574, -104.98891 39.55...
# 2    POLYGON ((-104.78338 39.52756, -104.78339 39.5...
# 3    POLYGON ((-104.86821 39.41264, -104.86813 39.4...
# 4    POLYGON ((-104.99159 39.55006, -104.99174 39.5...
# ..                                                 ...
# ...
